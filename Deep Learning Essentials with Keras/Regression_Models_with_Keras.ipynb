# %%
pip install keras
# Out:
# Collecting keras
#   Downloading keras-2.8.0-py2.py3-none-any.whl (1.4 MB)
# Installing collected packages: keras
# Successfully installed keras-2.8.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

# %%
concrete_data = pd.read_csv('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0101EN/labs/data/concrete_data.csv')
concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %%
concrete_data.shape
# Out:
# (1030, 9)

# %%
concrete_data.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# 25%            0.000000        932.000000      730.950000     7.000000
# 50%            6.400000        968.000000      779.500000    28.000000
# 75%           10.200000       1029.400000      824.000000    56.000000
# max           32.200000       1145.000000      992.600000   365.000000
#
#           Strength
# count  1030.000000
# mean     35.817961
# std      16.705742
# min       2.330000
# 25%      23.710000
# 50%      34.445000
# 75%      46.135000
# max      82.600000

# %%
concrete_data.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %%
concrete_data_columns = concrete_data.columns

predictors = concrete_data[concrete_data_columns[concrete_data_columns != 'Strength']] # all columns except Strength
target = concrete_data['Strength'] # Strength column

# %%
predictors.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365
# 4             978.4           825.5  360

# %%
target.head()
# Out:
# 0    79.99
# 1    61.89
# 2    40.27
# 3    41.05
# 4    44.30
# Name: Strength, dtype: float64

# %%
predictors_norm = (predictors - predictors.mean()) / predictors.std()
predictors_norm.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221
# 4          0.070492        0.647569  4.976069

# %%
n_cols = predictors_norm.shape[1] # number of predictors

# %%
pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.8.0-cp38-cp38-win_amd64.whl (438.0 MB)
# Collecting astunparse>=1.6.0
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: setuptools in c:\users\sthar\anaconda3\lib\site-packages (from tensorflow) (52.0.0.post20210125)
# Collecting libclang>=9.0.1
#   Downloading libclang-13.0.0-py2.py3-none-win_amd64.whl (13.9 MB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.25.0-cp38-cp38-win_amd64.whl (1.5 MB)
# Collecting protobuf>=3.9.2
#   Downloading protobuf-3.20.1-cp38-cp38-win_amd64.whl (904 kB)
# Collecting keras-preprocessing>=1.1.1
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\sthar\anaconda3\lib\site-packages (from tensorflow) (1.12.1)
# Collecting tensorboard<2.9,>=2.8
#   Downloading tensorboard-2.8.0-py3-none-any.whl (5.8 MB)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\sthar\anaconda3\lib\site-packages (from tensorflow) (2.10.0)
# Collecting flatbuffers>=1.12
#   Downloading flatbuffers-2.0-py2.py3-none-any.whl (26 kB)
# Collecting google-pasta>=0.1.1
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting absl-py>=0.4.0
#   Downloading absl_py-1.0.0-py3-none-any.whl (126 kB)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in c:\users\sthar\anaconda3\lib\site-packages (from tensorflow) (2.8.0)
# Collecting termcolor>=1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Requirement already satisfied: six>=1.12.0 in c:\users\sthar\anaconda3\lib\site-packages (from tensorflow) (1.15.0)
# Collecting gast>=0.2.1
#   Downloading gast-0.5.3-py3-none-any.whl (19 kB)
# Collecting tf-estimator-nightly==2.8.0.dev2021122109
#   Downloading tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl (462 kB)
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.44.0-cp38-cp38-win_amd64.whl (3.4 MB)
# Requirement already satisfied: numpy>=1.20 in c:\users\sthar\anaconda3\lib\site-packages (from tensorflow) (1.20.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\sthar\anaconda3\lib\site-packages (from tensorflow) (3.7.4.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\sthar\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.36.2)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\sthar\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (2.25.1)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\sthar\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (1.0.1)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.3.6-py3-none-any.whl (97 kB)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.6.6-py2.py3-none-any.whl (156 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.0.0-py3-none-any.whl (9.1 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.8-py3-none-any.whl (39 kB)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting importlib-metadata>=4.4
#   Downloading importlib_metadata-4.11.3-py3-none-any.whl (18 kB)
# Requirement already satisfied: zipp>=0.5 in c:\users\sthar\anaconda3\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow) (3.4.1)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\sthar\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sthar\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\sthar\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sthar\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (1.26.4)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.0-py3-none-any.whl (151 kB)
# Building wheels for collected packages: termcolor
#   Building wheel for termcolor (setup.py): started
#   Building wheel for termcolor (setup.py): finished with status 'done'
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4829 sha256=0b2cab178b0218755d791e91f124bb55bf97d6dce4feb8e8e4027bf074e182dc
#   Stored in directory: c:\users\sthar\appdata\local\pip\cache\wheels\a0\16\9c\5473df82468f958445479c59e784896fa24f4a5fc024b0f501
# Successfully built termcolor
# Installing collected packages: pyasn1, rsa, pyasn1-modules, oauthlib, cachetools, requests-oauthlib, importlib-metadata, google-auth, tensorboard-plugin-wit, tensorboard-data-server, protobuf, markdown, grpcio, google-auth-oauthlib, absl-py, tf-estimator-nightly, termcolor, tensorflow-io-gcs-filesystem, tensorboard, opt-einsum, libclang, keras-preprocessing, google-pasta, gast, flatbuffers, astunparse, tensorflow
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 3.10.0
#     Uninstalling importlib-metadata-3.10.0:
# Note: you may need to restart the kernel to use updated packages.      Successfully uninstalled importlib-metadata-3.10.0
# Successfully installed absl-py-1.0.0 astunparse-1.6.3 cachetools-5.0.0 flatbuffers-2.0 gast-0.5.3 google-auth-2.6.6 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.44.0 importlib-metadata-4.11.3 keras-preprocessing-1.1.2 libclang-13.0.0 markdown-3.3.6 oauthlib-3.2.0 opt-einsum-3.3.0 protobuf-3.20.1 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-oauthlib-1.3.1 rsa-4.8 tensorboard-2.8.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.8.0 tensorflow-io-gcs-filesystem-0.25.0 termcolor-1.1.0 tf-estimator-nightly-2.8.0.dev2021122109

# %%
import keras

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
# define regression model
def regression_model():
    # create model
    model = Sequential()
    model.add(Dense(50, activation='relu', input_shape=(n_cols,)))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(1))
    
    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
# build the model
model = regression_model()

# %%
# fit the model
model.fit(predictors_norm, target, validation_split=0.3, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 23/23 - 1s - loss: 1639.0710 - val_loss: 1138.8708 - 860ms/epoch - 37ms/step
# Epoch 2/100
# 23/23 - 0s - loss: 1502.2385 - val_loss: 1005.9671 - 101ms/epoch - 4ms/step
# Epoch 3/100
# 23/23 - 0s - loss: 1276.6835 - val_loss: 794.8041 - 91ms/epoch - 4ms/step
# Epoch 4/100
# 23/23 - 0s - loss: 940.8286 - val_loss: 536.8569 - 98ms/epoch - 4ms/step
# Epoch 5/100
# 23/23 - 0s - loss: 585.5322 - val_loss: 315.5686 - 87ms/epoch - 4ms/step
# Epoch 6/100
# 23/23 - 0s - loss: 347.0592 - val_loss: 208.2651 - 89ms/epoch - 4ms/step
# Epoch 7/100
# 23/23 - 0s - loss: 267.5133 - val_loss: 177.8024 - 86ms/epoch - 4ms/step
# Epoch 8/100
# 23/23 - 0s - loss: 239.7487 - val_loss: 174.4700 - 86ms/epoch - 4ms/step
# Epoch 9/100
# 23/23 - 0s - loss: 221.6573 - val_loss: 169.9321 - 86ms/epoch - 4ms/step
# Epoch 10/100
# 23/23 - 0s - loss: 208.9715 - val_loss: 167.9679 - 93ms/epoch - 4ms/step
# Epoch 11/100
# 23/23 - 0s - loss: 198.2785 - val_loss: 164.4257 - 109ms/epoch - 5ms/step
# Epoch 12/100
# 23/23 - 0s - loss: 190.4491 - val_loss: 163.6321 - 104ms/epoch - 5ms/step
# Epoch 13/100
# 23/23 - 0s - loss: 183.8927 - val_loss: 163.0025 - 100ms/epoch - 4ms/step
# Epoch 14/100
# 23/23 - 0s - loss: 177.8874 - val_loss: 161.9942 - 104ms/epoch - 5ms/step
# Epoch 15/100
# 23/23 - 0s - loss: 172.5575 - val_loss: 158.2535 - 94ms/epoch - 4ms/step
# Epoch 16/100
# 23/23 - 0s - loss: 168.2771 - val_loss: 161.8912 - 95ms/epoch - 4ms/step
# Epoch 17/100
# 23/23 - 0s - loss: 163.9693 - val_loss: 158.0393 - 88ms/epoch - 4ms/step
# Epoch 18/100
# 23/23 - 0s - loss: 160.8826 - val_loss: 156.6861 - 101ms/epoch - 4ms/step
# Epoch 19/100
# 23/23 - 0s - loss: 158.7613 - val_loss: 158.5898 - 107ms/epoch - 5ms/step
# Epoch 20/100
# 23/23 - 0s - loss: 155.0106 - val_loss: 157.2463 - 117ms/epoch - 5ms/step
# Epoch 21/100
# 23/23 - 0s - loss: 152.5014 - val_loss: 159.5437 - 121ms/epoch - 5ms/step
# Epoch 22/100
# 23/23 - 0s - loss: 150.7049 - val_loss: 156.6680 - 111ms/epoch - 5ms/step
# Epoch 23/100
# 23/23 - 0s - loss: 148.7184 - val_loss: 158.0709 - 101ms/epoch - 4ms/step
# Epoch 24/100
# 23/23 - 0s - loss: 146.0483 - val_loss: 157.1359 - 104ms/epoch - 5ms/step
# Epoch 25/100
# 23/23 - 0s - loss: 144.7864 - val_loss: 160.4422 - 99ms/epoch - 4ms/step
# Epoch 26/100
# 23/23 - 0s - loss: 142.6384 - val_loss: 155.6418 - 97ms/epoch - 4ms/step
# Epoch 27/100
# 23/23 - 0s - loss: 140.4371 - val_loss: 159.1808 - 90ms/epoch - 4ms/step
# Epoch 28/100
# 23/23 - 0s - loss: 139.0247 - val_loss: 160.3553 - 90ms/epoch - 4ms/step
# Epoch 29/100
# 23/23 - 0s - loss: 137.4181 - val_loss: 159.5674 - 96ms/epoch - 4ms/step
# Epoch 30/100
# 23/23 - 0s - loss: 136.2522 - val_loss: 161.6537 - 98ms/epoch - 4ms/step
# Epoch 31/100
# 23/23 - 0s - loss: 134.5776 - val_loss: 158.2081 - 104ms/epoch - 5ms/step
# Epoch 32/100
# 23/23 - 0s - loss: 133.0930 - val_loss: 162.6246 - 112ms/epoch - 5ms/step
# Epoch 33/100
# 23/23 - 0s - loss: 131.4467 - val_loss: 161.2286 - 100ms/epoch - 4ms/step
# Epoch 34/100
# 23/23 - 0s - loss: 130.6352 - val_loss: 162.5715 - 94ms/epoch - 4ms/step
# Epoch 35/100
# 23/23 - 0s - loss: 128.9457 - val_loss: 160.6537 - 90ms/epoch - 4ms/step
# Epoch 36/100
# 23/23 - 0s - loss: 126.8869 - val_loss: 161.4245 - 95ms/epoch - 4ms/step
# Epoch 37/100
# 23/23 - 0s - loss: 126.1509 - val_loss: 162.1559 - 89ms/epoch - 4ms/step
# Epoch 38/100
# 23/23 - 0s - loss: 123.9696 - val_loss: 161.9393 - 97ms/epoch - 4ms/step
# Epoch 39/100
# 23/23 - 0s - loss: 121.9969 - val_loss: 161.2707 - 111ms/epoch - 5ms/step
# Epoch 40/100
# 23/23 - 0s - loss: 120.3575 - val_loss: 159.3069 - 113ms/epoch - 5ms/step
# Epoch 41/100
# 23/23 - 0s - loss: 118.4520 - val_loss: 160.9520 - 114ms/epoch - 5ms/step
# Epoch 42/100
# 23/23 - 0s - loss: 116.2603 - val_loss: 160.8795 - 109ms/epoch - 5ms/step
# Epoch 43/100
# 23/23 - 0s - loss: 113.9316 - val_loss: 160.6340 - 103ms/epoch - 4ms/step
# Epoch 44/100
# 23/23 - 0s - loss: 111.7965 - val_loss: 155.5023 - 97ms/epoch - 4ms/step
# Epoch 45/100
# 23/23 - 0s - loss: 109.0902 - val_loss: 158.8569 - 88ms/epoch - 4ms/step
# Epoch 46/100
# 23/23 - 0s - loss: 106.6970 - val_loss: 156.8021 - 90ms/epoch - 4ms/step
# Epoch 47/100
# 23/23 - 0s - loss: 104.2087 - val_loss: 160.4415 - 95ms/epoch - 4ms/step
# Epoch 48/100
# 23/23 - 0s - loss: 101.0849 - val_loss: 154.8245 - 89ms/epoch - 4ms/step
# Epoch 49/100
# 23/23 - 0s - loss: 98.4861 - val_loss: 152.5215 - 95ms/epoch - 4ms/step
# Epoch 50/100
# 23/23 - 0s - loss: 96.4246 - val_loss: 146.9147 - 108ms/epoch - 5ms/step
# Epoch 51/100
# 23/23 - 0s - loss: 92.9500 - val_loss: 153.0036 - 103ms/epoch - 4ms/step
# Epoch 52/100
# 23/23 - 0s - loss: 90.0755 - val_loss: 152.2758 - 109ms/epoch - 5ms/step
# Epoch 53/100
# 23/23 - 0s - loss: 86.8012 - val_loss: 153.3788 - 153ms/epoch - 7ms/step
# Epoch 54/100
# 23/23 - 0s - loss: 84.5332 - val_loss: 146.5523 - 105ms/epoch - 5ms/step
# Epoch 55/100
# 23/23 - 0s - loss: 81.3721 - val_loss: 147.2765 - 90ms/epoch - 4ms/step
# Epoch 56/100
# 23/23 - 0s - loss: 79.4607 - val_loss: 144.1606 - 88ms/epoch - 4ms/step
# Epoch 57/100
# 23/23 - 0s - loss: 76.5046 - val_loss: 144.2883 - 95ms/epoch - 4ms/step
# Epoch 58/100
# 23/23 - 0s - loss: 73.4894 - val_loss: 142.9753 - 100ms/epoch - 4ms/step
# Epoch 59/100
# 23/23 - 0s - loss: 70.9050 - val_loss: 138.5697 - 99ms/epoch - 4ms/step
# Epoch 60/100
# 23/23 - 0s - loss: 68.6527 - val_loss: 141.7793 - 108ms/epoch - 5ms/step
# Epoch 61/100
# 23/23 - 0s - loss: 66.9063 - val_loss: 134.9789 - 98ms/epoch - 4ms/step
# Epoch 62/100
# 23/23 - 0s - loss: 64.4597 - val_loss: 136.7892 - 97ms/epoch - 4ms/step
# Epoch 63/100
# 23/23 - 0s - loss: 62.5515 - val_loss: 133.5289 - 99ms/epoch - 4ms/step
# Epoch 64/100
# 23/23 - 0s - loss: 61.1929 - val_loss: 130.8634 - 96ms/epoch - 4ms/step
# Epoch 65/100
# 23/23 - 0s - loss: 59.8919 - val_loss: 136.1738 - 85ms/epoch - 4ms/step
# Epoch 66/100
# 23/23 - 0s - loss: 58.1980 - val_loss: 134.5812 - 93ms/epoch - 4ms/step
# Epoch 67/100
# 23/23 - 0s - loss: 55.7369 - val_loss: 135.4450 - 87ms/epoch - 4ms/step
# Epoch 68/100
# 23/23 - 0s - loss: 54.6722 - val_loss: 128.9706 - 105ms/epoch - 5ms/step
# Epoch 69/100
# 23/23 - 0s - loss: 53.2692 - val_loss: 133.7578 - 128ms/epoch - 6ms/step
# Epoch 70/100
# 23/23 - 0s - loss: 52.4762 - val_loss: 127.5759 - 107ms/epoch - 5ms/step
# Epoch 71/100
# 23/23 - 0s - loss: 50.4075 - val_loss: 129.1750 - 107ms/epoch - 5ms/step
# Epoch 72/100
# 23/23 - 0s - loss: 49.9284 - val_loss: 132.5708 - 107ms/epoch - 5ms/step
# Epoch 73/100
# 23/23 - 0s - loss: 48.9773 - val_loss: 126.3959 - 88ms/epoch - 4ms/step
# Epoch 74/100
# 23/23 - 0s - loss: 48.5347 - val_loss: 124.9647 - 88ms/epoch - 4ms/step
# Epoch 75/100
# 23/23 - 0s - loss: 46.7171 - val_loss: 127.1930 - 88ms/epoch - 4ms/step
# Epoch 76/100
# 23/23 - 0s - loss: 46.3670 - val_loss: 130.8140 - 91ms/epoch - 4ms/step
# Epoch 77/100
# 23/23 - 0s - loss: 45.4863 - val_loss: 132.3522 - 85ms/epoch - 4ms/step
# Epoch 78/100
# 23/23 - 0s - loss: 44.2453 - val_loss: 129.6677 - 90ms/epoch - 4ms/step
# Epoch 79/100
# 23/23 - 0s - loss: 43.5649 - val_loss: 123.0414 - 91ms/epoch - 4ms/step
# Epoch 80/100
# 23/23 - 0s - loss: 42.4947 - val_loss: 130.9218 - 99ms/epoch - 4ms/step
# Epoch 81/100
# 23/23 - 0s - loss: 42.0584 - val_loss: 125.8920 - 103ms/epoch - 4ms/step
# Epoch 82/100
# 23/23 - 0s - loss: 41.9181 - val_loss: 121.8431 - 99ms/epoch - 4ms/step
# Epoch 83/100
# 23/23 - 0s - loss: 41.4199 - val_loss: 126.4272 - 100ms/epoch - 4ms/step
# Epoch 84/100
# 23/23 - 0s - loss: 40.0350 - val_loss: 135.2342 - 95ms/epoch - 4ms/step
# Epoch 85/100
# 23/23 - 0s - loss: 39.7778 - val_loss: 130.5871 - 86ms/epoch - 4ms/step
# Epoch 86/100
# 23/23 - 0s - loss: 39.1598 - val_loss: 130.0210 - 86ms/epoch - 4ms/step
# Epoch 87/100
# 23/23 - 0s - loss: 38.7306 - val_loss: 132.2029 - 96ms/epoch - 4ms/step
# Epoch 88/100
# 23/23 - 0s - loss: 38.5347 - val_loss: 134.2349 - 96ms/epoch - 4ms/step
# Epoch 89/100
# 23/23 - 0s - loss: 38.2020 - val_loss: 136.2955 - 104ms/epoch - 5ms/step
# Epoch 90/100
# 23/23 - 0s - loss: 37.2218 - val_loss: 129.3347 - 109ms/epoch - 5ms/step
# Epoch 91/100
# 23/23 - 0s - loss: 37.3752 - val_loss: 137.0974 - 108ms/epoch - 5ms/step
# Epoch 92/100
# 23/23 - 0s - loss: 36.5826 - val_loss: 136.8882 - 110ms/epoch - 5ms/step
# Epoch 93/100
# 23/23 - 0s - loss: 37.1904 - val_loss: 139.8331 - 94ms/epoch - 4ms/step
# Epoch 94/100
# 23/23 - 0s - loss: 35.6158 - val_loss: 127.2325 - 95ms/epoch - 4ms/step
# Epoch 95/100
# 23/23 - 0s - loss: 35.3735 - val_loss: 141.8418 - 97ms/epoch - 4ms/step
# Epoch 96/100
# 23/23 - 0s - loss: 35.2478 - val_loss: 131.8418 - 87ms/epoch - 4ms/step
# Epoch 97/100
# 23/23 - 0s - loss: 34.9952 - val_loss: 141.9377 - 88ms/epoch - 4ms/step
# Epoch 98/100
# 23/23 - 0s - loss: 34.4940 - val_loss: 130.9749 - 95ms/epoch - 4ms/step
# Epoch 99/100
# 23/23 - 0s - loss: 34.1748 - val_loss: 130.5340 - 99ms/epoch - 4ms/step
# Epoch 100/100
# 23/23 - 0s - loss: 34.0135 - val_loss: 141.2976 - 106ms/epoch - 5ms/step
